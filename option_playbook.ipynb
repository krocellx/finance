# %%
import opstrat as op

# %%
op_1 = {'op_type':'c','strike':110,'tr_type':'s','op_pr':2}
op_2 = {'op_type':'p','strike':95,'tr_type':'s','op_pr':6}
op.multi_plotter(spot=100, op_list=[op_1,op_2])

# %%
op_1 = {'op_type':'c','strike':110,'tr_type':'b','op_pr':1}
op_2 = {'op_type':'p','strike':110,'tr_type':'b','op_pr':1}
op.multi_plotter(op_list=[op_1,op_2])

# %%
op_1 = {'op_type':'c','strike':150,'tr_type':'b','op_pr':0}
op_2 = {'op_type':'c','strike':150,'tr_type':'b','op_pr':0}
op_3 = {'op_type':'c','strike':140,'tr_type':'s','op_pr':0}
op.multi_plotter(spot=160,op_list=[op_1,op_2, op_3])
