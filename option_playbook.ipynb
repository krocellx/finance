# %%
import opstrat as op

# %%
op_1 = {'op_type':'c','strike':110,'tr_type':'s','op_pr':2}
op_2 = {'op_type':'p','strike':95,'tr_type':'s','op_pr':6}
op.yf_plotter(ticker='SHY', op_list=[op_1,op_2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_134168/2380681934.py in <module>
#       1 op_1 = {'op_type':'c','strike':110,'tr_type':'s','op_pr':2}
#       2 op_2 = {'op_type':'p','strike':95,'tr_type':'s','op_pr':6}
# ----> 3 op.yf_plotter(ticker='SHY', op_list=[op_1,op_2])
#
# D:\Programs\Anaconda3\lib\site-packages\opstrat\yf.py in yf_plotter(ticker, exp, spot_range, op_list, save, file)
#     101
#     102         strike=op['strike']
# --> 103         check_strike(df, strike)
#     104         op_pr=df[df.strike==strike].lastPrice.sum()
#     105         try:
#
# D:\Programs\Anaconda3\lib\site-packages\opstrat\yf.py in check_strike(df, strike)
#      84     def check_strike(df, strike):
#      85         if strike not in df.strike.unique():
# ---> 86             raise ValueError('Option for the given Strike Price not available!')
#      87
# ...

# %%
op_1 = {'op_type':'c','strike':110,'tr_type':'b','op_pr':1}
op_2 = {'op_type':'p','strike':110,'tr_type':'b','op_pr':1}
op.multi_plotter(op_list=[op_1,op_2])

# %%
op_1 = {'op_type':'c','strike':83,'tr_type':'s','op_pr':1}
op_2 = {'op_type':'c','strike':84,'tr_type':'b','op_pr':0.4}
op.multi_plotter(spot=83.98, spot_range=3, op_list=[op_1,op_2])

# %%
op_1 = {'op_type':'c','strike':84,'tr_type':'s','op_pr':0.3}
op_2 = {'op_type':'c','strike':85,'tr_type':'b','op_pr':0.1}
op.multi_plotter(spot=83.98, spot_range=1.5, op_list=[op_1,op_2])

# %%
op_1 = {'op_type':'p','strike':2700,'tr_type':'b','op_pr':8.2}
op_2 = {'op_type':'p','strike':3000,'tr_type':'s','op_pr':31.85}
op_3 = {'op_type':'c','strike':3000,'tr_type':'s','op_pr':221.65}
op_4 = {'op_type':'c','strike':3300,'tr_type':'b','op_pr':68.6}
op.multi_plotter(spot=3192.5, op_list=[op_1, op_2, op_3, op_4])

# %%
op.payoff_calculator
